# %%
cd UNet-Pytorch-Customdataset/
# Out:
# /home/lkarimi/LNN-ImageSegmentation/LNN-ImageSegmentation/UNet-Pytorch-Customdataset
# /home/lkarimi/myvenv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python train.py --epochs 20 --batch-size 16
# Out:
# INFO: Using device cuda
# INFO: Creating dataset with 290 examples
# INFO: Scanning mask files to determine unique values
# 100%|███████████████████████████████████████| 290/290 [00:00<00:00, 2138.79it/s]
# INFO: Unique mask values: [0, 255]
# Epoch 1/20:   6%|█▊                           | 16/261 [00:01<00:21, 11.44img/s]loss: 1.112504243850708
# loss: 1.0154578685760498
# Epoch 1/20:  18%|█████▎                       | 48/261 [00:01<00:05, 36.90img/s]loss: 0.8641402721405029
#
# ...
# Validation round: 100%|████████████████████████| 1/1 [00:00<00:00,  2.67batch/s]
#                                                                                 Validation Dice Score: 3.235318957184319e-11
# ...
# Epoch 1/20:  37%|██████████▋                  | 96/261 [00:02<00:03, 51.10img/s]loss: 0.612729549407959
#
# ...
# Validation round: 100%|████████████████████████| 1/1 [00:00<00:00,  3.31batch/s]
# ...

# %%
# !python predict.py --model ./o_checkpoints/checkpoint_epoch20.pth -i ./data/imgs/0.jpg --viz --output ./0_OUT.jpg
# Out:
# INFO: Loading model ./o_checkpoints/checkpoint_epoch20.pth
# INFO: Using device cuda
# ...
